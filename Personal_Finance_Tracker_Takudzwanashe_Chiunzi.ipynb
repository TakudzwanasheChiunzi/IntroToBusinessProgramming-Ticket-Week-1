# %% [markdown]
# <a href="https://colab.research.google.com/github/TakudzwanasheChiunzi/Taku-ISYS2001-Lab-Exit-Tickets/blob/main/Personal_Finance_Tracker_Takudzwanashe_Chiunzi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 4: Building Your Finance Tracker Foundation (15 minutes)
#
# ### Start Your Semester Project
#
# Create a new notebook called "Personal_Finance_Tracker" and build the foundation:

# %%
print("=== Personal Finance Tracker v0.1 ===")
print("Week 3: Smart Budget Decisions")
print()

# User setup
name = input("Enter your name: ")
monthly_income = float(input("Enter your monthly income: $"))

print(f"\nWelcome to your finance tracker, {name}!")
print(f"Monthly income: ${monthly_income:.2f}")

# This week's feature: Expense categorisation
print("\n--- Expense Entry ---")
expense_amount = float(input("Enter an expense: $"))
expense_description = input("What was this expense for? ")


# REFINED VERSION - Your Working Budget Tracker
# # 1. Initialize variables
total_expenses = 0.0
expense_count = 1
username = "Taku"
theme = "golden"
currency = "BWP"
goals = "flying fist class"

#SECOND EDIT TO CODE
goals2 = "creating generational wealth"

# 2. Get the monthly income
monthly_income = float(input("Enter your total monthly income: "))

# 3. Collect 3 expenses using a loop
print("\nPlease enter your top 3 monthly expenses:")
while expense_count <= 3:
    expense_value = float(input(f"Enter amount for expense {expense_count}: "))
    total_expenses = total_expenses + expense_value # Add to the running total
    expense_count = expense_count + 1               # Move to the next count

# 4. Calculate the remaining balance
remaining_budget = monthly_income - total_expenses

# 5. Display the results and the warning logic
print("-" * 30)
print(f"Total Income:   ${monthly_income:,.2f}")
print(f"Total Expenses: ${total_expenses:,.2f}")
print(f"Remaining:      ${remaining_budget:,.2f}")

# 6. The "Warning" Logic (Conditional Statement)
if remaining_budget < 0:
    print("\n⚠️ WARNING: You are over budget! Your expenses exceed your income.")
elif remaining_budget == 0:
    print("\nNote: You have exactly $0 left. Your budget is perfectly balanced.")
else:
    print("\nGreat job! You are within your budget.")

# TAKU'S ATTEMPT
# Import datetime to timestamp your work
from datetime import datetime

# Collect user information
username = input("Howdy stranger! What do they call you in these parts?")
theme = input("What app theme suits your fancy? (e.g., gold, anime, dark) ")
currency = input("What currency are you using? (e.g., BWP, MUR, ZAR) ")
goals = input("Now why are you trying to save money?...seriously why? (e.g., New Car, Holiday) ")
goals2 = input("Is there anything else your saving your money towards?")




if expense >= 100:
  category = "Major Expense"
  print("You need to reduce your expenses, try substituting or using the 80/20 rule of money.")
elif expense >= 50:
  category = "Moderate Expense"
  print("You do not have anything to be concerned about at this stage, but track your expenses regardless.")
elif expense >= 10:
    category = "Minor Expense"
    print("You do not have anything to worry about but still keep tracking your expenses and save idle income.")
else:
  category = "Small Purchase"
  print("Wow!I've never seen such low expenses🧐")
print(f"This is a {category}")


print("=== Budget Limit Checker ===")

# Get user's budget and expense
monthly_budget = float(input("Enter your monthly budget: $"))
expense = float(input("Enter expense amount: $"))


percentage_of_budget = (expense / monthly_budget) * 100

if percentage_of_budget > 50:
  category = "Major Expense"
  print("Major purchase - think carefully")
  print(f"You have spent {percentage_of_budget}% of your budget, this is a {category}")
elif percentage_of_budget > 25:
  category = "Significant Expense"
  print("Significant expense")
  print(f"You have spent {percentage_of_budget}% of your budget, this is a {category}")
elif percentage_of_budget > 10:
  category = "Moderate Expense"
  print("Moderate expense")
  print(f"You have spent {percentage_of_budget}% of your budget, this is a {category}")
else:
  category = "Minor expense - within budget"
  print(f"This is a {category} and you have spent {percentage_of_budget}% of your budget")

print("=== Savings Goal Tracker ===")

goal_amount = float(input("Savings goal: $"))
current_savings = float(input("Current savings: $"))

# Your task: Calculate percentage and give encouraging feedback
# 100%+: "Goal achieved! Consider a new goal."
# 75-99%: "Almost there! You're doing great."
# 50-74%: "Halfway there - keep it up!"
# 25-49%: "Good progress, stay consistent"
# Under 25%: "Just getting started - you've got this!"

percentage_of_goal = (current_savings/goal_amount) * 100

if percentage_of_goal >= 100:
  goal = "Goal achieved! Consider a new goal."
elif percentage_of_goal >= 75 and percentage_of_goal <=99:
  goal = "Almost there! You're doing great."
elif percentage_of_goal >= 50 and percentage_of_goal <= 74:
  goal = "Halfway there - keep it up!"
elif percentage_of_goal >= 25 and percentage_of_goal <=49:
  goal = "Good progress, stay consistent"
else:
  goal = "Just getting started - you've got this!"
print(f"You've saved {percentage_of_goal}% of your goal. {goal}")

print("=== Smart Purchase Advisor ===")

# Get financial information
available_money = float(input("How much money do you have available? $"))
purchase_price = float(input("How much does the item cost? $"))
monthly_income = float(input("What's your monthly income? $"))

# Calculate affordability percentage
# affordability_ratio = purchase_price / available_money # This line might cause ZeroDivisionError if available_money is 0, and isn't used in the provided logic

# Your task: Build the decision logic
# Consider:
# - Can they afford it at all?
# - Is it a large percentage of their available money?
# - Is it reasonable compared to their income?
# - What advice should you give?
# Suggestion: Use multiple if/elif conditions to give personalised advice

if purchase_price <= available_money and purchase_price <= monthly_income:
  print("You can afford to buy it!")
elif purchase_price <= available_money and purchase_price >= monthly_income:
  print("You can afford to buy it but it's not a reasonable expense. Save up for it instead!")
elif purchase_price >= available_money and purchase_price <= monthly_income:
  print("You can't afford it right now, start saving for it instead.")
else:
  print("You can't afford it and it's not reasonable, but if you want it start saving for it bit by bit.")

if purchase_price <= available_money and purchase_price <= monthly_income:
  category = ("Affordable and reasonable")
elif purchase_price <= available_money and purchase_price >= monthly_income:
  category = ("Affordable but not reasonable")
elif purchase_price >= available_money and purchase_price <= monthly_income:
  category = ("Not affordable but reasonable")
else:
  category = ("Not affordable and not reasonable")
print(f"This is a {category}")

expense_type = input("Is this a necessity or a luxury?")

if expense_type == "necessity" and purchase_price <= available_money and purchase_price <= monthly_income:
  print("Go ahead and buy it!")
elif expense_type == "necessity" and purchase_price <= available_money and purchase_price >= monthly_income:
  print("You should purchase it, but review your expenses to make sure you always have money saved up for your needs!")
elif expense_type == "necessity" and purchase_price >= available_money and purchase_price <= monthly_income:
  print("Take a look at some options to obtain emergency funds and let's start planning your finances for the future")
elif expense_type == "necessity" and purchase_price >= available_money and purchase_price >= monthly_income:
  print("Contact your bank to hlp you navigate how best to allocate your finances and get some emergency funds")
else:
  print("This is a luxury, I cannot tell you how to live your life, but please do not spend above your means.")
